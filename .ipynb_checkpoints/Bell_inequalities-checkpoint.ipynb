# %% [markdown]
# #   Неравенства Белла, квантовая запутанность
#
#     Я водитель грузовика. Ок, прямо сейчас не водитель. У меня сейчас другая работа. Но это не суть. Мы с парнями из гаража регулярно встречаемся, обсуждаем разное. У нас в гараже много любителей почитать-посмотреть всякий научпоп. И как-то мы решили разобраться с квантовой запутанностью,  неравенствами Белла и нелокальностью.
#
#     Началось все с того, что Макс с Аликом заспорили. Макс топит за суперпозицию состояний и фундаментальную неопределенность, Алик - за скрытые параметры. Каждый конечно - в меру своего шоферского понимания проблемы. Я говорю, чего вы спорите? Все ведь уже давно решено. Есть парадоркс ЭПР, есть неравенства Белла. Проводили реальные эксперименты. В реальных экспериментах неравенства не выполняются. Значит нет никаких скрытых параметров.
#
#     Макс говорит, да, все есть, но Алика это не убеждает, потому, что он этого не понимает. Я, говорит, тоже не понимаю, но верю. А он не верит. А объяснить ему я, говорит, не могу, потому, что, как сказал, сам не понимаю. Пытались сесть разобраться вдвоем, только запутали друг друга. Вот у тебя, говорит, с математикой-физикой вроде порядок, может ты нам объяснишь?
#
#     Ну, у меня в школе действительно с математикой было неплохо. На олимпиады даже ездил, бывало, районные, грамоты там получал, а то и книжку какую-нибудь, фломастеры. А насчет физики - это он мне польстил, конечно. Какими-то кусками я ее учил, фрагментарно. Тут знаю, тут не знаю...
#
#     Но, говорю, давай. Попробуем. Прямо вот сходу, говорю, не готов, но я подберу какую-нибудь статью попроще, на Хабре, например. Такую, чисто для шоферов. И мы ее разберем. Осмотрелся, выбрал вот эту:
# https://habr.com/ru/post/540620/
#
#     Сели мы разбираться.

# %%
import math
import numpy as np
import matplotlib as mpl
import pylab
# importing matplotlib module 
from matplotlib import pyplot as plt 

theta = range(90)
polar_prob = list(theta)

for i in theta:
    polar_prob[i] = math.cos(math.radians(i)) * math.cos(math.radians(i))
  
# Function to plot 
plt.plot(theta, polar_prob) 

# Adding Title
plt.title("поляризация")
# Labeling the axes
plt.xlabel("угол")
plt.ylabel("вероятность")
  
# function to show the plot 
plt.show()

#*****************************************************

theta_full = range(360)

sinuses = list(theta_full)
cosinuses = list(theta_full)

for i in theta_full:
    sinuses[i] = math.sin(math.radians(i))
    cosinuses[i] = math.cos(math.radians(i))
    
# Создаем форматер
xformatter = mpl.ticker.NullFormatter()
yformatter = mpl.ticker.NullFormatter()

# Установка форматера для оси X
#plt.axes().xaxis.set_major_formatter(xformatter)
#plt.axes().yaxis.set_major_formatter(yformatter)

plt.gca().set_aspect('equal')


plt.plot(sinuses, cosinuses) 
plt.show()
